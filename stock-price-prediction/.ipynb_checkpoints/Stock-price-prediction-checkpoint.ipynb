# %% [markdown]
# # Welcome to Learn ML 2021 Grand AI Challenge! 🎉
#
# The year 2020 has been an outlier year for finance analysts. Most of the past models have failed to give out great results on the 2020 financial data creating a need for more robust models to handle such outliers. Hence with this challenge, we wish to test your analytical modelling skills not for 1 stock but 5 to see if you have what it takes to create a model that can give predictions for the outlier 2020 year. All the best for the challenge!
#
# The aim of this challenge is to predict the closing prices of 5 stocks using the given data.
#
# The dataset consists of 3 files:
#
#     new_train.csv (for training)
#     new_test.csv (for test)
#     new_sample_submission.csv (for sample submission format)
#
# This data should be used to train the model, no additional data is allowed to be used for the training process.
#
# A "new_sample_submission.csv" is also provided for ease of the participants. To know the exact submission format, please check out "Submission Guidelines".

# %%
import warnings
warnings.simplefilter('ignore')

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('Data/new_train.csv')
test = pd.read_csv('Data/new_test.csv')

# %%
train = train.sort_values('Date')
test = test.sort_values('Date')

# %%
train.head()
# Out:
#          Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0  2010-06-01        1889.7       1890.00      1838.00        1855.10
# 1  2010-06-02        1848.0       1862.75      1828.00        1853.05
# 2  2010-06-03        1864.1       1910.00      1864.10        1905.60
# 3  2010-06-04        1906.0       1909.80      1880.10        1885.70
# 4  2010-06-07        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  \
# 0       1855.75          568273   105457457545000        285.40        285.95
# 1       1842.82          945167   174177161135000        284.00        284.80
# 2       1893.91          679689   128727119355000        283.00        286.85
# 3       1889.21          509435    96242800140000        288.85        291.80
# 4       1873.32          961913   180196832650000        285.00        289.10
#
#    ...  VWAP-Stock-4  Volume-Stock-4  Turnover-Stock-4  Open-Stock-5  \
# 0  ...        844.44         3878011   327474904340000        1235.0
# 1  ...        838.31         3320996   278403743240000        1195.0
# 2  ...        853.51         2494522   212910342645000        1211.0
# 3  ...        862.85         2963920   255740999120000        1240.0
# 4  ...        839.89         3471483   291567400640000        1218.6
#
#    High-Stock-5  Low-Stock-5  Close-Stock-5  VWAP-Stock-5  Volume-Stock-5  \
# 0       1238.00       1177.0        1181.70       1197.29         1786082
# 1       1206.95       1168.5        1201.15       1189.87         1307410
# 2       1248.00       1211.0        1242.30       1231.63         1482919
# 3       1258.00       1240.0        1245.45       1249.72         1454459
# 4       1225.00       1196.0        1214.80       1209.27         1424594
#
#    Turnover-Stock-5
# 0   213845404410000
# 1   155564994855000
# 2   182640434320000
# 3   181767075850000
# 4   172272511430000
#
# [5 rows x 36 columns]

# %% [markdown]
# ###### Meaning of VWAP,Volume and Turnover of a stock
#
# * **Volume Weighted Average Price (VWAP)?**
#
# The volume weighted average price (VWAP) is a trading benchmark used by traders that gives the average price a security has traded at throughout the day, based on both volume and price. It is important because it provides traders with insight into both the trend and value of a security.
#
#                                     VWAP =(∑(Price * Volume))/∑Volume
#
# * **Volume** is measured in the number of shares traded on that day.
# * **Stock Turnover** is the rate at which a company's goods are sold and replaced.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 298
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              299 non-null    object
#  1   Open-Stock-1      299 non-null    float64
#  2   High-Stock-1      299 non-null    float64
#  3   Low-Stock-1       299 non-null    float64
#  4   Close-Stock-1     299 non-null    float64
#  5   VWAP-Stock-1      299 non-null    float64
#  6   Volume-Stock-1    299 non-null    int64
#  7   Turnover-Stock-1  299 non-null    int64
#  8   Open-Stock-2      299 non-null    float64
#  9   High-Stock-2      299 non-null    float64
#  10  Low-Stock-2       299 non-null    float64
#  11  Close-Stock-2     299 non-null    float64
#  12  VWAP-Stock-2      299 non-null    float64
#  13  Volume-Stock-2    299 non-null    int64
#  14  Turnover-Stock-2  299 non-null    int64
#  15  Open-Stock-3      299 non-null    float64
#  16  High-Stock-3      299 non-null    float64
#  17  Low-Stock-3       299 non-null    float64
#  18  Close-Stock-3     299 non-null    float64
#  19  VWAP-Stock-3      299 non-null    float64
#  20  Volume-Stock-3    299 non-null    int64
#  21  Turnover-Stock-3  299 non-null    int64
#  22  Open-Stock-4      299 non-null    float64
#  23  High-Stock-4      299 non-null    float64
#  24  Low-Stock-4       299 non-null    float64
#  25  Close-Stock-4     299 non-null    float64
#  26  VWAP-Stock-4      299 non-null    float64
#  27  Volume-Stock-4    299 non-null    int64
#  28  Turnover-Stock-4  299 non-null    int64
#  29  Open-Stock-5      299 non-null    float64
#  30  High-Stock-5      299 non-null    float64
#  31  Low-Stock-5       299 non-null    float64
#  32  Close-Stock-5     299 non-null    float64
#  33  VWAP-Stock-5      299 non-null    float64
#  34  Volume-Stock-5    299 non-null    int64
#  35  Turnover-Stock-5  299 non-null    int64
# dtypes: float64(25), int64(10), object(1)
# memory usage: 86.4+ KB

# %%
train['Date'] = train['Date'].astype('datetime64')
test['Date'] = test['Date'].astype('datetime64')

# %%
train.isna().sum()
# Out:
# Date                0
# Open-Stock-1        0
# High-Stock-1        0
# Low-Stock-1         0
# Close-Stock-1       0
# VWAP-Stock-1        0
# Volume-Stock-1      0
# Turnover-Stock-1    0
# Open-Stock-2        0
# High-Stock-2        0
# Low-Stock-2         0
# Close-Stock-2       0
# VWAP-Stock-2        0
# Volume-Stock-2      0
# Turnover-Stock-2    0
# Open-Stock-3        0
# High-Stock-3        0
# Low-Stock-3         0
# Close-Stock-3       0
# VWAP-Stock-3        0
# Volume-Stock-3      0
# Turnover-Stock-3    0
# Open-Stock-4        0
# High-Stock-4        0
# Low-Stock-4         0
# Close-Stock-4       0
# VWAP-Stock-4        0
# Volume-Stock-4      0
# Turnover-Stock-4    0
# Open-Stock-5        0
# High-Stock-5        0
# Low-Stock-5         0
# Close-Stock-5       0
# VWAP-Stock-5        0
# Volume-Stock-5      0
# Turnover-Stock-5    0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# Date                0
# Open-Stock-1        0
# High-Stock-1        0
# Low-Stock-1         0
# Close-Stock-1       0
# VWAP-Stock-1        0
# Volume-Stock-1      0
# Turnover-Stock-1    0
# Open-Stock-2        0
# High-Stock-2        0
# Low-Stock-2         0
# Close-Stock-2       0
# VWAP-Stock-2        0
# Volume-Stock-2      0
# Turnover-Stock-2    0
# Open-Stock-3        0
# High-Stock-3        0
# Low-Stock-3         0
# Close-Stock-3       0
# VWAP-Stock-3        0
# Volume-Stock-3      0
# Turnover-Stock-3    0
# Open-Stock-4        0
# High-Stock-4        0
# Low-Stock-4         0
# Close-Stock-4       0
# VWAP-Stock-4        0
# Volume-Stock-4      0
# Turnover-Stock-4    0
# Open-Stock-5        0
# High-Stock-5        0
# Low-Stock-5         0
# Close-Stock-5       0
# VWAP-Stock-5        0
# Volume-Stock-5      0
# Turnover-Stock-5    0
# dtype: int64

# %% [markdown]
# # Creating different datasets for each stock

# %%
stock1 = train[['Date', 'Open-Stock-1', 'High-Stock-1', 'Low-Stock-1', 'Close-Stock-1','VWAP-Stock-1', 'Volume-Stock-1', 'Turnover-Stock-1']]
stock2 = train[['Date', 'Open-Stock-2', 'High-Stock-2', 'Low-Stock-2', 'Close-Stock-2','VWAP-Stock-2', 'Volume-Stock-2', 'Turnover-Stock-2']]
stock3 = train[['Date', 'Open-Stock-3', 'High-Stock-3', 'Low-Stock-3', 'Close-Stock-3','VWAP-Stock-3', 'Volume-Stock-3', 'Turnover-Stock-3']]
stock4 = train[['Date', 'Open-Stock-4', 'High-Stock-4', 'Low-Stock-4', 'Close-Stock-4','VWAP-Stock-4', 'Volume-Stock-4', 'Turnover-Stock-4']]
stock5 = train[['Date', 'Open-Stock-5', 'High-Stock-5', 'Low-Stock-5', 'Close-Stock-5','VWAP-Stock-5', 'Volume-Stock-5', 'Turnover-Stock-5']]

# %%
tstock1 = test[['Date', 'Open-Stock-1', 'High-Stock-1', 'Low-Stock-1','VWAP-Stock-1', 'Volume-Stock-1', 'Turnover-Stock-1']]
tstock2 = test[['Date', 'Open-Stock-2', 'High-Stock-2', 'Low-Stock-2','VWAP-Stock-2', 'Volume-Stock-2', 'Turnover-Stock-2']]
tstock3 = test[['Date', 'Open-Stock-3', 'High-Stock-3', 'Low-Stock-3','VWAP-Stock-3', 'Volume-Stock-3', 'Turnover-Stock-3']]
tstock4 = test[['Date', 'Open-Stock-4', 'High-Stock-4', 'Low-Stock-4','VWAP-Stock-4', 'Volume-Stock-4', 'Turnover-Stock-4']]
tstock5 = test[['Date', 'Open-Stock-5', 'High-Stock-5', 'Low-Stock-5','VWAP-Stock-5', 'Volume-Stock-5', 'Turnover-Stock-5']]

# %%
def distribution_func(data):
    fig,ax = plt.subplots(3,2,figsize = (15,15))
    l = list(data.drop('Date',axis = 1).columns)
    for i in range(3):
        for j in range(2):
            sns.kdeplot(l[j],data = data,ax = ax[i,j])
            l.pop(j)

# %%
distribution_func(stock1)

# %%
def scatter_func(data):
    fig,ax = plt.subplots(3,2,figsize = (15,15))
    l = list(data.drop('Date',axis = 1).columns)
    for i in range(3):
        for j in range(2):
            sns.scatterplot(l[j],data['Close-Stock-1'],data = data,ax = ax[i,j])
            l.pop(j)

# %%
scatter_func(stock1)

# %% [markdown]
# ###### As is apparent from the scatter and the distribution, we have few outliers in stock 1

# %%
sns.boxplot(stock1['Close-Stock-1'])
plt.show()

# %%
stock1 = stock1[stock1['Close-Stock-1']>700]

# %%
stock1.head()
# Out:
#         Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0 2010-06-01        1889.7       1890.00      1838.00        1855.10
# 1 2010-06-02        1848.0       1862.75      1828.00        1853.05
# 2 2010-06-03        1864.1       1910.00      1864.10        1905.60
# 3 2010-06-04        1906.0       1909.80      1880.10        1885.70
# 4 2010-06-07        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1
# 0       1855.75          568273   105457457545000
# 1       1842.82          945167   174177161135000
# 2       1893.91          679689   128727119355000
# 3       1889.21          509435    96242800140000
# 4       1873.32          961913   180196832650000

# %%
sns.boxplot(stock1['Close-Stock-1'])
plt.show()

# %% [markdown]
# ###### Outlier has been removed

# %%
distribution_func(stock1)

# %%
scatter_func(stock1)

# %% [markdown]
# ###### Data is much more normally distributed now

# %%
stock1.head()
# Out:
#         Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0 2010-06-01        1889.7       1890.00      1838.00        1855.10
# 1 2010-06-02        1848.0       1862.75      1828.00        1853.05
# 2 2010-06-03        1864.1       1910.00      1864.10        1905.60
# 3 2010-06-04        1906.0       1909.80      1880.10        1885.70
# 4 2010-06-07        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1
# 0       1855.75          568273   105457457545000
# 1       1842.82          945167   174177161135000
# 2       1893.91          679689   128727119355000
# 3       1889.21          509435    96242800140000
# 4       1873.32          961913   180196832650000

# %%
stock1.shape
# Out:
# (284, 8)

# %%
284*0.2
# Out:
# 56.800000000000004

# %% [markdown]
# ###### creating a manual train test split since this is time series data and we have to predict future stock prices

# %%
s1_train = stock1.head(284-56)
s1_test = stock1.tail(56)

# %%
fig,ax = plt.subplots(1,2,figsize = (15,6))
sns.scatterplot('Volume-Stock-1','Turnover-Stock-1',data = stock1,ax = ax[0])
sns.scatterplot('VWAP-Stock-1','Turnover-Stock-1',data = stock1,ax = ax[1])
